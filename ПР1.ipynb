# %% [markdown]
# # ПР1

# %%
import pandas as pd
import sqlite3
mov = sqlite3.connect('/content/movies.sqlite')
mv = pd.read_sql("SELECT * from movies", mov)
mv
# Out:
#          id                            original_title     budget  popularity  \
# 0     43597                                    Avatar  237000000         150
# 1     43598  Pirates of the Caribbean: At World's End  300000000         139
# 2     43599                                   Spectre  245000000         107
# 3     43600                     The Dark Knight Rises  250000000         112
# ...     ...                                       ...        ...         ...
# 4769  48396                                 Newlyweds       9000           0
# 4770  48397                 Signed, Sealed, Delivered          0           1
# 4771  48398                          Shanghai Calling          0           0
# 4772  48399                         My Date with Drew          0           1
#
#      release_date     revenue                                     title  \
# 0      2009-12-10  2787965087                                    Avatar
# ...

# %%
mv.shape
# Out:
# (4773, 13)

# %%
mv.head()
# Out:
#       id                            original_title     budget  popularity  \
# 0  43597                                    Avatar  237000000         150
# 1  43598  Pirates of the Caribbean: At World's End  300000000         139
# 2  43599                                   Spectre  245000000         107
# 3  43600                     The Dark Knight Rises  250000000         112
# 4  43601                               John Carter  260000000          43
#
#   release_date     revenue                                     title  \
# 0   2009-12-10  2787965087                                    Avatar
# 1   2007-05-19   961000000  Pirates of the Caribbean: At World's End
# 2   2015-10-26   880674609                                   Spectre
# 3   2012-07-16  1084939099                     The Dark Knight Rises
# 4   2012-03-07   284139100                               John Carter
#
#    vote_average  vote_count  \
# 0           7.2       11800
# 1           6.9        4500
# ...

# %%
mv.id
# Out:
# 0       43597
# 1       43598
# 2       43599
# 3       43600
# 4       43601
#         ...
# 4768    48395
# 4769    48396
# 4770    48397
# 4771    48398
# 4772    48399
# Name: id, Length: 4773, dtype: int64

# %%
mv["original_title"]
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4768                                 El Mariachi
# 4769                                   Newlyweds
# 4770                   Signed, Sealed, Delivered
# 4771                            Shanghai Calling
# 4772                           My Date with Drew
# Name: original_title, Length: 4773, dtype: object

# %%
mv["original_title"][5]
# Out:
# 'Spider-Man 3'

# %%
mv.iloc[0]
# Out:
# id                                                            43597
# original_title                                               Avatar
# budget                                                    237000000
# popularity                                                      150
# release_date                                             2009-12-10
# revenue                                                  2787965087
# title                                                        Avatar
# vote_average                                                    7.2
# vote_count                                                    11800
# overview          In the 22nd century, a paraplegic Marine is di...
# tagline                                 Enter the World of Pandora.
# uid                                                           19995
# director_id                                                    4762
# Name: 0, dtype: object

# %%
mv.iloc[:, 0]
# Out:
# 0       43597
# 1       43598
# 2       43599
# 3       43600
# 4       43601
#         ...
# 4768    48395
# 4769    48396
# 4770    48397
# 4771    48398
# 4772    48399
# Name: id, Length: 4773, dtype: int64

# %%
mv.iloc[:3, 1]
# Out:
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# Name: original_title, dtype: object

# %%
mv.iloc[[3, 4, 5], 1]
# Out:
# 3    The Dark Knight Rises
# 4              John Carter
# 5             Spider-Man 3
# Name: original_title, dtype: object

# %%
mv.iloc[-5:]
# Out:
#          id             original_title  budget  popularity release_date  \
# 4768  48395                El Mariachi  220000          14   1992-09-04
# 4769  48396                  Newlyweds    9000           0   2011-12-26
# 4770  48397  Signed, Sealed, Delivered       0           1   2013-10-13
# 4771  48398           Shanghai Calling       0           0   2012-05-03
# 4772  48399          My Date with Drew       0           1   2005-08-05
#
#       revenue                      title  vote_average  vote_count  \
# 4768  2040920                El Mariachi           6.6         238
# 4769        0                  Newlyweds           5.9           5
# 4770        0  Signed, Sealed, Delivered           7.0           6
# 4771        0           Shanghai Calling           5.7           7
# 4772        0          My Date with Drew           6.3          16
#
#                                                overview  \
# 4768  El Mariachi just wants to play his guitar and ...
# ...

# %%
mv.loc[0, 'title']
# Out:
# 'Avatar'

# %%
mv.loc[:, ['original_title', 'release_date', 'vote_average', 'director_id']]
# Out:
#                                 original_title release_date  vote_average  \
# 0                                       Avatar   2009-12-10           7.2
# 1     Pirates of the Caribbean: At World's End   2007-05-19           6.9
# 2                                      Spectre   2015-10-26           6.3
# 3                        The Dark Knight Rises   2012-07-16           7.6
# 4                                  John Carter   2012-03-07           6.1
# ...                                        ...          ...           ...
# 4768                               El Mariachi   1992-09-04           6.6
# 4769                                 Newlyweds   2011-12-26           5.9
# 4770                 Signed, Sealed, Delivered   2013-10-13           7.0
# 4771                          Shanghai Calling   2012-05-03           5.7
# 4772                         My Date with Drew   2005-08-05           6.3
#
#       director_id
# 0            4762
# 1            4763
# 2            4764
# ...

# %%
mv.set_index("id")
# Out:
#                                  original_title     budget  popularity  \
# id
# 43597                                    Avatar  237000000         150
# 43598  Pirates of the Caribbean: At World's End  300000000         139
# 43599                                   Spectre  245000000         107
# 43600                     The Dark Knight Rises  250000000         112
# 43601                               John Carter  260000000          43
# ...                                         ...        ...         ...
# 48395                               El Mariachi     220000          14
# 48396                                 Newlyweds       9000           0
# 48397                 Signed, Sealed, Delivered          0           1
# 48398                          Shanghai Calling          0           0
# 48399                         My Date with Drew          0           1
#
#       release_date     revenue                                     title  \
# id
# ...

# %%
mv.loc[(mv.popularity >= 100) & ((mv['vote_average'] >= 7.0) | (mv['vote_count'] < 3000))]
# Out:
#          id                              original_title     budget  \
# 0     43597                                      Avatar  237000000
# 3     43600                       The Dark Knight Rises  250000000
# 7     43604                     Avengers: Age of Ultron  280000000
# 11    43608                           Quantum of Solace  200000000
# 12    43609  Pirates of the Caribbean: Dead Man's Chest  200000000
# ...     ...                                         ...        ...
# 3232  46829                                Pulp Fiction    8000000
# 3337  46934                               The Godfather    6000000
# 3717  47316             One Flew Over the Cuckoo's Nest    3000000
# 3862  47462                                    Whiplash    3300000
# 4069  47671                                  It Follows    2000000
#
#       popularity release_date     revenue  \
# 0            150   2009-12-10  2787965087
# 3            112   2012-07-16  1084939099
# ...

# %%
mv.loc[mv['budget'].isin([280000000, 220000, 3000000])]
# Out:
#          id                                     original_title     budget  \
# 7     43604                            Avengers: Age of Ultron  280000000
# 2777  46374                                    Excessive Force    3000000
# 3717  47316                    One Flew Over the Cuckoo's Nest    3000000
# 3781  47381                                      Shooting Fish    3000000
# 3861  47461                                              Choke    3000000
# 3886  47486                              Paranormal Activity 2    3000000
# 3890  47490  A Nightmare on Elm Street Part 2: Freddy's Rev...    3000000
# 3891  47491                                 A Room with a View    3000000
# 3892  47492                                          The Purge    3000000
# 3893  47493                                           Sinister    3000000
# 3894  47494                    Martin Lawrence Live: Runteldat    3000000
# 3895  47495                              Cat on a Hot Tin Roof    3000000
# ...

# %%
mv.loc[mv['title'].notnull()]
# Out:
#          id                            original_title     budget  popularity  \
# 0     43597                                    Avatar  237000000         150
# 1     43598  Pirates of the Caribbean: At World's End  300000000         139
# 2     43599                                   Spectre  245000000         107
# 3     43600                     The Dark Knight Rises  250000000         112
# 4     43601                               John Carter  260000000          43
# ...     ...                                       ...        ...         ...
# 4768  48395                               El Mariachi     220000          14
# 4769  48396                                 Newlyweds       9000           0
# 4770  48397                 Signed, Sealed, Delivered          0           1
# 4771  48398                          Shanghai Calling          0           0
# 4772  48399                         My Date with Drew          0           1
#
# ...

# %%
mv.loc[mv['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, original_title, budget, popularity, release_date, revenue, title, vote_average, vote_count, overview, tagline, uid, director_id]
# Index: []

# %%
mv['index_new'] = range(len(mv), 0, -1)
mv
# Out:
#          id                            original_title     budget  popularity  \
# 0     43597                                    Avatar  237000000         150
# 1     43598  Pirates of the Caribbean: At World's End  300000000         139
# 2     43599                                   Spectre  245000000         107
# 3     43600                     The Dark Knight Rises  250000000         112
# 4     43601                               John Carter  260000000          43
# ...     ...                                       ...        ...         ...
# 4768  48395                               El Mariachi     220000          14
# 4769  48396                                 Newlyweds       9000           0
# 4770  48397                 Signed, Sealed, Delivered          0           1
# 4771  48398                          Shanghai Calling          0           0
# 4772  48399                         My Date with Drew          0           1
#
# ...

# %%
import numpy as np

# %%
teams = pd.read_csv("/content/teams.csv", index_col=0)
pd.set_option('display.max_rows', 9)
teams
# Out:
#                           Name                           League  LeagueId  \
# ID
# 1                      Arsenal       English Premier League (1)        13
# 2                  Aston Villa       English Premier League (1)        13
# 1808    Brighton & Hove Albion       English Premier League (1)        13
# 1796                   Burnley       English Premier League (1)        13
# ...                        ...                              ...       ...
# 110989              Caracas FC  Venezuelan Primera División (1)      2019
# 111332   Estudiantes de Mérida  Venezuelan Primera División (1)      2019
# 114623     Llaneros de Guanare  Venezuelan Primera División (1)      2019
# 112912               Zamora FC  Venezuelan Primera División (1)      2019
#
#         Overall  Attack  Midfield  Defence  TransferBudget  DomesticPrestige  \
# ID
# 1            80      87        79       78        80000000                 7
# ...

# %%
teams.Defence.describe()
# Out:
# count    730.000000
# mean      68.431507
# std        5.201967
# min       54.000000
# 25%       65.000000
# 50%       68.000000
# 75%       71.000000
# max       86.000000
# Name: Defence, dtype: float64

# %%
teams.League.describe()
# Out:
# count               730
# unique               52
# top       International
# freq                 49
# Name: League, dtype: object

# %%
teams.Midfield.mean()
# Out:
# 68.9876712328767

# %%
teams.League.unique()
# Out:
# array(['English Premier League (1)', 'French Ligue 1 (1)',
#        'German 1. Bundesliga (1)', 'Italian Serie A (1)',
#        'Spain Primera Division (1)', 'Argentina Primera División \xa0(1)',
#        'Australian Hyundai A-League (1)',
#        'Austrian Football Bundesliga (1)',
#        'Belgian Jupiler Pro League (1)',
#        'Campeonato Brasileiro Série A (1)',
#        'Chilian Campeonato Nacional (1)', 'Chinese Super League (1)',
#        'Colombian Liga Postobón (1)', 'Croatian Prva HNL (1)',
#        'Czech Republic Gambrinus Liga (1)', 'Danish Superliga (1)',
#        'Ecuadorian Serie A (1)', 'English League Championship (2)',
#        'English League One (3)', 'English League Two (4)',
#        'Finnish Veikkausliiga (1)', 'French Ligue 2 (2)',
#        'German 2. Bundesliga (2)', 'German 3. Bundesliga (3)',
#        'Greek Super League (1)', 'Holland Eredivisie (1)',
#        'International', 'Italian Serie B (2)',
# ...

# %%
teams.League.value_counts()
# Out:
# International                         49
# USA Major League Soccer (1)           26
# Argentina Primera División  (1)       25
# English League Championship (2)       24
#                                       ..
# South African Premier Division (1)     2
# Croatian Prva HNL (1)                  1
# UAE Arabian Gulf League (1)            1
# Finnish Veikkausliiga (1)              1
# Name: League, Length: 52, dtype: int64

# %%
age_math_mean = teams.StartingAverageAge.mean()
teams.StartingAverageAge.map(lambda p: p - age_math_mean)
# Out:
# ID
# 1        -0.711233
# 2        -2.211233
# 1808     -0.911233
# 1796      1.288767
#             ...
# 110989   -2.311233
# 111332    0.988767
# 114623   -1.311233
# 112912   -0.911233
# Name: StartingAverageAge, Length: 730, dtype: float64

# %%
def remean_math(row):
    row.StartingAverageAge = row.StartingAverageAge - age_math_mean
    return row

teams.apply(remean_math, axis='columns')
# Out:
#                           Name                           League  LeagueId  \
# ID
# 1                      Arsenal       English Premier League (1)        13
# 2                  Aston Villa       English Premier League (1)        13
# 1808    Brighton & Hove Albion       English Premier League (1)        13
# 1796                   Burnley       English Premier League (1)        13
# ...                        ...                              ...       ...
# 110989              Caracas FC  Venezuelan Primera División (1)      2019
# 111332   Estudiantes de Mérida  Venezuelan Primera División (1)      2019
# 114623     Llaneros de Guanare  Venezuelan Primera División (1)      2019
# 112912               Zamora FC  Venezuelan Primera División (1)      2019
#
#         Overall  Attack  Midfield  Defence  TransferBudget  DomesticPrestige  \
# ID
# 1            80      87        79       78        80000000                 7
# ...

# %%
age_math_mean = teams.StartingAverageAge.mean()
teams.StartingAverageAge - age_math_mean
# Out:
# ID
# 1        -0.711233
# 2        -2.211233
# 1808     -0.911233
# 1796      1.288767
#             ...
# 110989   -2.311233
# 111332    0.988767
# 114623   -1.311233
# 112912   -0.911233
# Name: StartingAverageAge, Length: 730, dtype: float64

# %%
teams.Name + " - " + teams.League
# Out:
# ID
# 1                      Arsenal - English Premier League (1)
# 2                  Aston Villa - English Premier League (1)
# 1808      Brighton & Hove Albion - English Premier Leagu...
# 1796                   Burnley - English Premier League (1)
#                                 ...
# 110989         Caracas FC - Venezuelan Primera División (1)
# 111332    Estudiantes de Mérida - Venezuelan Primera Div...
# 114623    Llaneros de Guanare - Venezuelan Primera Divis...
# 112912          Zamora FC - Venezuelan Primera División (1)
# Length: 730, dtype: object

# %%
teams.groupby('Overall').Overall.count()
# Out:
# Overall
# 55    1
# 56    2
# 57    1
# 58    3
#      ..
# 82    6
# 83    9
# 84    4
# 85    3
# Name: Overall, Length: 30, dtype: int64

# %%
teams.groupby('League').Overall.max()
# Out:
# League
# Argentina Primera División  (1)     76
# Australian Hyundai A-League (1)     66
# Austrian Football Bundesliga (1)    73
# Belgian Jupiler Pro League (1)      75
#                                     ..
# USA Major League Soccer (1)         72
# Ukrainian Premier League (1)        75
# Uruguayan Primera División (1)      71
# Venezuelan Primera División (1)     63
# Name: Overall, Length: 52, dtype: int64

# %%
teams.groupby(['League']).IntPrestige.agg([min, max, len])
# Out:
#                                   min  max  len
# League
# Argentina Primera División  (1)     1    9   25
# Australian Hyundai A-League (1)     1    5   12
# Austrian Football Bundesliga (1)    1    6   12
# Belgian Jupiler Pro League (1)      1    5   18
# ...                               ...  ...  ...
# USA Major League Soccer (1)         1    6   26
# Ukrainian Premier League (1)        6    7    2
# Uruguayan Primera División (1)      1    6    6
# Venezuelan Primera División (1)     1    5    6
#
# [52 rows x 3 columns]

# %%
league_teams = teams.groupby(['Name', 'League']).Players.agg([min])
league_teams
# Out:
#                                                        min
# Name                  League
# 1. FC Heidenheim 1846 German 2. Bundesliga (2)          30
# 1. FC Kaiserslautern  German 3. Bundesliga (3)          28
# 1. FC Köln            German 1. Bundesliga (1)          31
# 1. FC Magdeburg       German 3. Bundesliga (3)          28
# ...                                                    ...
# Çaykur Rizespor       Turkish Süper Lig (1)             30
# Örebro SK             Swedish Allsvenskan (1)           26
# Östersunds FK         Swedish Allsvenskan (1)           26
# Śląsk Wrocław         Polish T-Mobile Ekstraklasa (1)   27
#
# [730 rows x 1 columns]

# %%
mi = league_teams.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
league_teams.reset_index()
# Out:
#                       Name                           League  min
# 0    1. FC Heidenheim 1846         German 2. Bundesliga (2)   30
# 1     1. FC Kaiserslautern         German 3. Bundesliga (3)   28
# 2               1. FC Köln         German 1. Bundesliga (1)   31
# 3          1. FC Magdeburg         German 3. Bundesliga (3)   28
# ..                     ...                              ...  ...
# 726        Çaykur Rizespor            Turkish Süper Lig (1)   30
# 727              Örebro SK          Swedish Allsvenskan (1)   26
# 728          Östersunds FK          Swedish Allsvenskan (1)   26
# 729          Śląsk Wrocław  Polish T-Mobile Ekstraklasa (1)   27
#
# [730 rows x 3 columns]

# %%
league_teams = league_teams.reset_index()
league_teams.sort_values(by='min')
# Out:
#                        Name                              League  min
# 36                 Al Fayha    Saudi Abdul L. Jameel League (1)   18
# 629  St. Patrick's Athletic  Rep. Ireland Airtricity League (1)   19
# 487             Perth Glory     Australian Hyundai A-League (1)   19
# 31                Al Adalah    Saudi Abdul L. Jameel League (1)   19
# ..                      ...                                 ...  ...
# 688           VfB Stuttgart            German 1. Bundesliga (1)   33
# 467  Olympique de Marseille                  French Ligue 1 (1)   33
# 389                   Lazio                 Italian Serie A (1)   33
# 621                  Spezia                 Italian Serie A (1)   33
#
# [730 rows x 3 columns]

# %%
league_teams.sort_values(by='min', ascending=False)
# Out:
#                        Name                              League  min
# 449        Newcastle United          English Premier League (1)   33
# 679             Valencia CF          Spain Primera Division (1)   33
# 517     Racing Club de Lens                  French Ligue 1 (1)   33
# 51               Angers SCO                  French Ligue 1 (1)   33
# ..                      ...                                 ...  ...
# 629  St. Patrick's Athletic  Rep. Ireland Airtricity League (1)   19
# 31                Al Adalah    Saudi Abdul L. Jameel League (1)   19
# 37                 Al Hazem    Saudi Abdul L. Jameel League (1)   19
# 36                 Al Fayha    Saudi Abdul L. Jameel League (1)   18
#
# [730 rows x 3 columns]

# %%
league_teams.sort_index()
# Out:
#                       Name                           League  min
# 0    1. FC Heidenheim 1846         German 2. Bundesliga (2)   30
# 1     1. FC Kaiserslautern         German 3. Bundesliga (3)   28
# 2               1. FC Köln         German 1. Bundesliga (1)   31
# 3          1. FC Magdeburg         German 3. Bundesliga (3)   28
# ..                     ...                              ...  ...
# 726        Çaykur Rizespor            Turkish Süper Lig (1)   30
# 727              Örebro SK          Swedish Allsvenskan (1)   26
# 728          Östersunds FK          Swedish Allsvenskan (1)   26
# 729          Śląsk Wrocław  Polish T-Mobile Ekstraklasa (1)   27
#
# [730 rows x 3 columns]

# %%
league_teams.sort_values(by=['League', 'min'])
# Out:
#                       Name                           League  min
# 68        Atlético Tucumán  Argentina Primera División  (1)   25
# 154    Club Atlético Colón  Argentina Primera División  (1)   26
# 57      Arsenal de Sarandí  Argentina Primera División  (1)   27
# 55      Argentinos Juniors  Argentina Primera División  (1)   28
# ..                     ...                              ...  ...
# 10   AC Mineros de Guayana  Venezuelan Primera División (1)   25
# 725              Zamora FC  Venezuelan Primera División (1)   28
# 225  Estudiantes de Mérida  Venezuelan Primera División (1)   29
# 129             Caracas FC  Venezuelan Primera División (1)   30
#
# [730 rows x 3 columns]

# %%
teams.dtypes
# Out:
# Name                   object
# League                 object
# LeagueId                int64
# Overall                 int64
#                        ...
# IntPrestige             int64
# Players                 int64
# StartingAverageAge    float64
# AllTeamAverageAge     float64
# Length: 13, dtype: object

# %%
teams.Overall.astype('float64')
# Out:
# ID
# 1         80.0
# 2         76.0
# 1808      76.0
# 1796      76.0
#           ...
# 110989    63.0
# 111332    63.0
# 114623    59.0
# 112912    60.0
# Name: Overall, Length: 730, dtype: float64

# %%
print(teams.index.dtype)
teams[pd.isnull(teams.League)]
# Out:
# int64
# Empty DataFrame
# Columns: [Name, League, LeagueId, Overall, Attack, Midfield, Defence, TransferBudget, DomesticPrestige, IntPrestige, Players, StartingAverageAge, AllTeamAverageAge]
# Index: []

# %%
teams.League.replace("English Premier League (1)", "English Premier League")
# Out:
# ID
# 1                  English Premier League
# 2                  English Premier League
# 1808               English Premier League
# 1796               English Premier League
#                        ...
# 110989    Venezuelan Primera División (1)
# 111332    Venezuelan Primera División (1)
# 114623    Venezuelan Primera División (1)
# 112912    Venezuelan Primera División (1)
# Name: League, Length: 730, dtype: object

# %%
teams.rename(columns={'LeagueId': 'LeagueNumber'})
# Out:
#                           Name                           League  LeagueNumber  \
# ID
# 1                      Arsenal       English Premier League (1)            13
# 2                  Aston Villa       English Premier League (1)            13
# 1808    Brighton & Hove Albion       English Premier League (1)            13
# 1796                   Burnley       English Premier League (1)            13
# ...                        ...                              ...           ...
# 110989              Caracas FC  Venezuelan Primera División (1)          2019
# 111332   Estudiantes de Mérida  Venezuelan Primera División (1)          2019
# 114623     Llaneros de Guanare  Venezuelan Primera División (1)          2019
# 112912               Zamora FC  Venezuelan Primera División (1)          2019
#
#         Overall  Attack  Midfield  Defence  TransferBudget  DomesticPrestige  \
# ID
# 1            80      87        79       78        80000000                 7
# ...

# %%
dr = pd.read_sql("SELECT * from directors", mov)
dr
# Out:
#                    name    id  gender      uid department
# 0         James Cameron  4762       2     2710  Directing
# 1        Gore Verbinski  4763       2     1704  Directing
# 2            Sam Mendes  4764       2       39  Directing
# 3     Christopher Nolan  4765       2      525  Directing
# ...                 ...   ...     ...      ...        ...
# 2345   Neill Dela Llana  7107       0  1174437  Directing
# 2346        Scott Smith  7108       0  1219158  Directing
# 2347        Daniel Hsia  7109       2   208138  Directing
# 2348   Brian Herzlinger  7110       2    85563  Directing
#
# [2349 rows x 5 columns]

# %%
drt = dr.loc[:, ['id', 'name']].rename(columns={'id': 'director_id'})
mv = pd.merge(mv, drt, on='director_id',  how = 'left').drop(['director_id'], axis = 1)
mv
# Out:
#          id                            original_title     budget  popularity  \
# 0     43597                                    Avatar  237000000         150
# 1     43598  Pirates of the Caribbean: At World's End  300000000         139
# 2     43599                                   Spectre  245000000         107
# 3     43600                     The Dark Knight Rises  250000000         112
# ...     ...                                       ...        ...         ...
# 4769  48396                                 Newlyweds       9000           0
# 4770  48397                 Signed, Sealed, Delivered          0           1
# 4771  48398                          Shanghai Calling          0           0
# 4772  48399                         My Date with Drew          0           1
#
#      release_date     revenue                                     title  \
# 0      2009-12-10  2787965087                                    Avatar
# ...
