# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('/content/line_reg_1_1.txt', header = None, names=['Population', 'Profit'])
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6b7bd52f5dab> in <module>
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 6 data = pd.read_csv('/content/line_reg_1_1.txt', header = None, names=['Population', 'Profit'])
#       7 data.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from sklearn import datasets, linear_model
cols = data.shape[1]
X = data.iloc[:,0:cols-1]
y = data.iloc[:,cols-1:cols]
regr = linear_model.LinearRegression()
regr.fit(X, y)
regr.coef_
# Out:
# array([[1.19303364]])

# %%
diabetes_y_pred = regr.predict(X)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(X, diabetes_y_pred, 'r', label='Линия минимальной ошибки')
ax.scatter(data.Population, data.Profit, label='Обучающие данные')
ax.legend(loc=2)
ax.set_xlabel('Население')
ax.set_ylabel('Прибыль')
ax.set_title('Зависимость прибыли от числа людей в городе')
# Out:
# Text(0.5, 1.0, 'Зависимость прибыли от числа людей в городе')
